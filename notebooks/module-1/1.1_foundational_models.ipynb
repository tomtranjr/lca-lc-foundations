# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon has no government or capital city, since it’s not a country. Any future lunar settlements would be planned by space agencies and international agreements, not a national capital. If you’re thinking of a fictional or proposed future scenario, tell me which story or idea you have in mind and I can share examples.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 781, 'prompt_tokens': 13, 'total_tokens': 794, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EOAygZushyCivRajneSRCbKQqedN7', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0a262-c225-7880-93da-6ec354295f7d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 781, 'total_tokens': 794, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon has no government or capital city, since it’s not a country. Any future lunar settlements would be planned by space agencies and international agreements, not a national capital. If you’re thinking of a fictional or proposed future scenario, tell me which story or idea you have in mind and I can share examples.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-EOAygZushyCivRajneSRCbKQqedN7',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 781,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 704,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cache_write_tokens': None,
#                                            'cached_tokens': 0},
#                  'total_tokens': 794}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0,
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government and has no capital or official population. If you’re imagining fiction, you could invent a capital like “Lunapolis” or similar.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
# model = init_chat_model(model="claude-sonnet-4-6")

# response = model.invoke("What's the capital of the Moon?")
# print(response.content)

# %%
# from langchain_google_genai import ChatGoogleGenerativeAI

# model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

# response = model.invoke("What's the capital of the Moon?")
# print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
# agent = create_agent(model="claude-sonnet-4-6")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]},
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='4d43adeb-d5ec-45d0-8b24-9c1881b2b07b'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government, so it has no capital. If you’re thinking of a fictional or future lunar colony, tell me the work or context and I can look up what they called its capital.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 572, 'prompt_tokens': 13, 'total_tokens': 585, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EOCKe8WOE72PMUCcL1hQWSxfkXrwW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0a2b2-39f9-76d0-a574-a43835248cf1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 572, 'total_tokens': 585, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})]}

# %%
print(response["messages"][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. If you’re thinking of a fictional or future lunar colony, tell me the work or context and I can look up what they called its capital.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {
        "messages": [
            HumanMessage(content="What's the capital of the Moon?"),
            AIMessage(content="The capital of the Moon is Luna City."),
            HumanMessage(content="Interesting, tell me more about Luna City"),
        ],
    },
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='83483838-c6e9-4ce6-a738-d1439927a79e'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='37b56e85-49a2-4c71-820e-ced1ec2e47a6', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='9e3a4044-460e-4489-97b4-655106166c36'),
#               AIMessage(content='A quick correction: there isn’t a real capital of the Moon. Luna City is a fictional idea you might use in a story or game. If you’d like, I can build out a detailed fictional version for you. Here’s a ready-to-use world-building concept you can drop into a sci‑fi tale or RPG.\n\nOverview\nLuna City is the first permanent lunar metropolis, built along the rim of Shackleton Crater near the Moon’s south pole. It’s a self-sustaining outpost focused on science, ISRU (in-situ resource utilization), and sustainable living. The city blends advanced robotics, 3D-printed habitats, and radiation-shielded domes with a surprisingly human culture shaped by long lunar nights and endless sunlit days in a 14/Earth-day cycle simulated by artificial lighting.\n\nLocation, layout and districts\n- Location: Shackleton Crater rim, near permanently shadowed craters for ice, with a panoramic view of the lunar farside.\n- Central hub: The Helium Gate, a domed atrium that acts as the civic and trade heart, housing the council chamber and the market.\n- Habitat rings: Several interconnected hexagonal modules (resilient, radiation-shielded), hosting living quarters, labs, and workshops.\n- Key districts:\n  - Ice Bay: icy deposits mined for water and fuel production.\n  - Greenhouse Crescent: vertical farming and biolab facilities supplying food and air regeneration.\n  - Archive Quarter: data vaults and a public museum of lunar science and Earth history.\n  - Dockyard Terra: multipurpose landing pads, maintenance bays, and the rover/rail systems.\n  - Arts and Echoes: cultural venues, libraries, broadcast studios, and performance spaces to counter isolation.\n\nGovernance, economy and society\n- Governance: A two-tier system with a Civic Assembly (representatives from districts) and a Merit Council (experts in life support, mining, and science). Decisions require both practical consensus and scientific review.\n- Population: A few thousand residents and researchers, plus rotating crews and students.\n- Economy: \n  - ISRU-based production (water, oxygen, fuel from ice and regolith).\n  - 3D-printed goods and construction services.\n  - Scientific research contracts, mining of volatiles, and telemetry/data services for Earth and orbital habitats.\n  - Tourism-lite (orbital visitors and short stays) and outreach programs.\n- Society and daily life: Residents follow a 24-hour work cycle with artificial daylight and circadian-friendly sleep schedules. Community life centers on shared facilities, with clubs, tutoring, and art/music to combat isolation.\n\nTechnology and infrastructure\n- Life support: Closed-loop air/w water systems, advanced hydroponics and algae photobioreactors, regenerative life support.\n- Energy: Hybrid solar arrays with nuclear-backed backups; thermal storage to cope with long nights.\n- Transport: Surface rail and maglev-like rovers; tethered elevators on the crater rim; airless-skywalks between domes.\n- Construction: 3D-printed regolith bricks, inflatable habitat modules, and modular expansion cores.\n- Security and health: Radiation shielding, micro-meteorite defense, telemedicine, autonomous maintenance bots.\n\nCulture and conflicts (tone ideas)\n- Culture: A blend of scientific curiosity and frontier nostalgia; festivals like “Sunrise to Shadow” celebrate the lunar day-night cycle, with concerts in low gravity.\n- Conflicts: Resource allocation debates, debates about independence versus Earth oversight, AI governance vs. human oversight, and the psychological toll of long lunar nights.\n\nSample scene (brief)\nThe glow of artificial dawn spilled across Luna City as Aira checked the ice bay sensors. A rover thudded in from the rim, hauling a load of excavated regolith. In the Archive Quarter, Maya synchronized the data streams from Earth with the lunar project files, watching a holographic map bloom with new routes. For the first time in a month, a visitor from Earth would speak with the council ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {
        "messages": [
            HumanMessage(
                content="Tell me all about Luna City, the capital of the Moon",
            ),
        ],
    },
    stream_mode="messages",
):
    # token is a message chunk with token content
    # metadata contains which node produced the token

    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional setting, not a real place. If you’re building a world, a story, or a game, here’s a thorough concept you can adapt or expand. It imagines Luna City as the Moon’s political and cultural capital in a future where humanity has settled and organized life around the lunar environment.
#
# Core concept
# - Name: Luna City
# - Role: Capital of the Moon, administrative center for lunar governance, research, trade, and culture. A hub where Earth-based diplomacy, lunar industry, and off-world communities intersect.
# - Vibe: A mix of high-tech efficiency and rugged, communal resilience. Think gleaming solar spires, modular habitat blocks, and quiet neighborhoods built into cliffs and crater rims.
#
# History and timeline (conflict, growth, and power)
# - Early phase (late 21st – early 22nd century): Lunar bases focused on resource extraction and research. No central capital yet; settlements are scattered across several craters and rims.
# - Rise of the Lunar Authority: A political federation forms to coordinate water ice extraction, solar energy, and radiation shielding. Administrative centers cluster to form a de facto capital.
# - Establishment of Luna City: The city grows around a major polar crater rim with abundant sunlight access and ice deposits. It becomes the symbolic and practical heart of lunar governance.
# - Modern era: Luna City evolves into a cultural capital with universities, museums, media, and a robust spaceport economy. It hosts annual interplanetary conferences and lunar fairs.
#
# Government and politics
# - System: A semi-democratic federation with a lunar council (legislative) and a chief administrator (executive). Citizens are born on the Moon or long-term lunar residents; Earth-born diplomats and corporate leaders participate through representation.
# - Districts and governance: Special districts manage water security, solar energy, mining, science, education, and culture. A Lunar Court handles civil disputes, while a Research Assembly oversees science ethics and space tech regulation.
# - Legal framework: Closed-loop resource management, environmental protections for regolith and ice, and a rights charter for lunar settlers (privacy, mobility, housing, and safety in a harsh environment).
# - Security: A mixed force of civil defense, police with EVA protocols, and planetary defense liaison teams. Emphasis on radiation safety, debris shielding, and cyber-physical security for critical infrastructure.
#
# Geography and districts
# - Location: A crater rim with near-surface ice deposits and extended sunlight portions, optimized for energy capture and water supply. Vaulted corridors connect surface habitats to underground or crater-floor facilities.
# - Key districts:
#   - Administrative Spire District: Government offices, the Lunar Assembly, courts, and the Chief Administrator’s residence.
#   - The Solar Ring: Massive solar farms and energy storage separated by transit corridors.
#   - Ice Gate Quarter: Water ice processing, fuel production, cryo-storage, and ice-mining operations.
#   - Education and Culture Precinct: Universities, libraries, museums, theaters, and broadcast studios.
#   - Research Crescent: Planetary science institutes, astrophysics labs, life sciences bays, and robotics workshops.
#   - Harbor of Dawn: The main spaceport, cargo terminals, passenger docks, and custom facilities.
#   -Residential Sectors: Modular housing clusters, with hydroponic farms on every deck and common areas designed for low-gravity recreation.
#
# Architecture and infrastructure
# - Architecture: A blend of modular, scalable habitats and monumental public buildings. Materials include engineered regolith bricks, ceramic composites, and light-steel frameworks. Aesthetic favors clean lines, reflective surfaces to manage heat, and cryo-insulated living spaces.
# - Life support: Closed-loop biospheres for food and oxygen; algae farms; hydroponics; underground cooling systems. Water recycling is highly advanced; ice is a vital resource for drinking water and fuel processing.
# - Radiation and micrometeoroids: Thick shielding in habitats; regolith shielding in surface facilities; autonomous repair drones and smart materials that self-heal micro-scratches.
# - Transportation:
#   - Surface: Maglev-like tram lines through pressure-tunneled corridors, all-electric rovers for EVA, and pedestrian airlocks.
#   - Orbital/Entry: A spaceport with passenger shuttles and freighters; cargo elevators; tethered transit to or from orbiting hubs.
#   - Local mobility: A network of pressurized skyways and safe EVA routes with real-time radiation and micrometeoroid alerts.
# - Energy: Predominantly solar power with large solar rings and arrays; energy storage in thermal and chemical batteries. Possible use of compact fusion or advanced fission reactors for baseload power, especially for night-side operations or heavy industry.
#
# Economy and technology
# - Economy pillars:
#   - Solar energy production and storage.
#   - Water ice mining and processing, fuel generation, and regolith mining services.
#   - Research, education, and cultural industries (universities, media, tourism).
#   - Spaceport logistics and interplanetary trade.
# - Key technologies:
#   - Closed-loop life support and agricultural biosystems.
#   - Advanced robotics, autonomous construction, and 3D-printed habitats.
#   - Rigorous radiation shielding and habitability optimization.
#   - In-situ resource utilization (ISRU) for fuel, water, and building materials.
# - Currency and trade: A lunar fractional reserve system tied to Earth-based currencies, with a local credit system for services, habitat rents, and transit. Trade routes with Earth, Mars, and other lunar outposts.
#
# Culture, daily life, and society
# - Population: A diverse mix of Earth-born settlers, long-term lunar residents, scientists, engineers, artists, and logistics professionals. Multinational neighborhoods exist, with local cultures blending through shared life in reduced gravity.
# - Language and education: A lingua franca for space life (Earthish or a Lunar Standard) used in official contexts, with multilingual education and community languages in neighborhoods. Strong emphasis on STEM, space ethics, and environmental stewardship.
# - Housing and community: Compact, modular apartments with communal kitchens, greenhouses, and shared workspaces. Common rooms for recreation, arts, and music. Schools emphasize space science, geology, and low-gravity physiology.
# - Health and safety: On-site medical centers with telepresence options from Earth; mental health programs addressing isolation and altered circadian rhythms; regular radiation/health monitoring.
# - Culture and identity: A lunar cultural renaissance—art inspired by Earth voyages and lunar landscapes, poetry and music echoing the vastness of space, festivals tied to solar cycles, and public art that doubles as shelter or solar collectors.
#
# Landmarks, institutions, and notable locations
# - The Spire Complex: A towering administrative hub with observation decks. Symbolizes lunar governance and serves as a venue for major announcements.
# - The Archive Dome: A giant data vault and library preserving lunar history, ISRU methods, and space exploration documents.
# - The Lighthouse of Dawn: A colossal solar-farm array with a reflective beacon used in navigation and ceremonial events.
# - The Council Gardens: Public green spaces under domes that manage temperature, humidity, and food production while offering leisure areas.
# - Harbor of Dawn Spaceport: The gateway for travelers, freighters, and diplomatic missions. Adjacent districts host markets and cultural exchange.
# - The Ice Gate: Processing facility where water ice is converted into fuel and drinking water; a critical economic asset.
# - The Research Crescent: Campus cluster with labs for astrophysics, planetary science, biology, robotics, and materials science.
#
# Notable people and institutions (examples to seed your world)
# - Chief Administrator Aria Kestrel: Charismatic leader focused on sustainable lunar governance and Earth-Luna diplomacy.
# - Lunar Council: A diverse group representing districts, research bodies, and civil society; known for public debates in the Spire Complex.
# - Lunar Institute of Tech and Culture: Largest university, blending engineering, arts, and ethics of space living.
# - Orbital Liaison Corps: Body that coordinates Earth-Luna relations and interplanetary trade.
#
# Science and exploration themes
# - Radiation and life in deep space: How communities adapt to continuous exposure and protect inhabitants.
# - ISRU and sustainable living: How Luna City recycles air, water, food, and energy, reducing dependence on Earth.
# - Social contracts in isolation: How governance, culture, and daily life adapt to long-term, close-knit lunar society.
# - Interplanetary diplomacy: Luna City as a hub for negotiations between Earth, Mars, and other Moon bases.
#
# Story seeds and world-building prompts
# - A solar flare disrupts Luna City’s energy grid, forcing a rapid transition to fallback systems and testing social cohesion.
# - A new ice vein is discovered beneath the Ice Gate, shifting the city’s geopolitical balance and igniting corporate competition.
# - A cultural festival at the Harbor of Dawn reveals a secret history about early lunar settlements and contested land rights.
# - An Earth-based delegation seeks a new treaty on resource sharing; old guard factions push back with a political intrigue subplot.
# - A scientist uncovers a biodiversity anomaly in a sealed biosphere, raising questions about terraforming ethics and planetary protection.
#
# Tips for crafting a convincing Luna City
# - Ground tech in plausible constraints: Moon gravity is 1/6 g; vacuum, radiation, and dust are constant design constraints. Base your architecture and daily routines on those realities.
# - Use modular, scalable design: Show how neighborhoods can be expanded or repurposed as the city grows or needs change.
# - Tie economics to ISRU realities: Make water, ice, and solar energy central to the city’s wealth; security of these resources is a constant tension.
# - Build a distinct culture: Create a local dialect, rituals around solar cycles, and public art that reflects life between Earth and space.
# - Create tension between Earth and Moon: Diplomacy, trade rules, and interplanetary politics add depth beyond internal city politics.
#
# If you tell me your preferred tone (hard sci-fi, space opera, utopian, noir, etc.), the medium (novel, game, screenplay), and how much detail you want, I can tailor Luna City further. Do you want a shorter baseline version for a quick reference, or a full, living-world dossier with hundreds of named places, families, and factions?
