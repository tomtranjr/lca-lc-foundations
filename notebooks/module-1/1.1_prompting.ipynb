# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke({"messages": [question]})

print(response["messages"][1].content)
# Out:
# There isn’t one. The Moon isn’t a country or sovereign entity, so it has no capital. If you’re thinking of fiction, some stories invent lunar cities with imagined capitals, but nothing real exists.

# %%
system_prompt = (
    "You are a science fiction writer, create a capital city at the users request."
)

scifi_agent = create_agent(model="gpt-5-nano", system_prompt=system_prompt)

response = scifi_agent.invoke({"messages": [question]})

print(response["messages"][1].content)
# Out:
# In reality, the Moon isn’t a country and has no capital. But in a sci‑fi setting, a compelling capital could be Lunaris Prime.
#
# - Location: perched along the rim of Shackleton Crater at the lunar south pole, where a ring of solar towers and glass domes catch the sunlight even during long nights.
# - The seat of government: the Lumen Citadel, a glittering arcology at the crater’s edge that houses the Lunar Assembly, the Ministry of Light, and the Central Archive.
# - City vibe: a city of vertical farms, glass walkways, and basalt-and-crystal spires. Transit glides along ring roads, and daylight is collected in giant solar canopies that double as public squares.
# - Notable features:
#   - Solstice Square, a vast plaza carved into the crater rim beneath a lattice of transparent nanomesh.
#   - The Prism Gate, a shimmering gateway built from ice crystals and solar glass.
#   - The Ice Archive, a subterranean repository preserving data in cryo-engraved crystal matrices.
#
# If you’d like a different name, location, or a darker/punkier vibe for the capital, I can tailor Lunaris Prime to your world. Would you prefer another concept or a different region on the Moon?

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(model="gpt-5-nano", system_prompt=system_prompt)

response = scifi_agent.invoke({"messages": [question]})

print(response["messages"][1].content)
# Out:
# Lunaria

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(model="gpt-5-nano", system_prompt=system_prompt)

response = scifi_agent.invoke({"messages": [question]})

print(response["messages"][1].content)
# Out:
# Name: Selene Prime
# Location: Shackleton Crater rim, Moon's south polar region
# Vibe: gleaming, austere, sovereign
# Economy: Helium-3 mining; water-ice processing; solar energy generation; robotics and construction; lunar research, education, and tourism

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel


class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str


agent = create_agent(
    model="gpt-5-nano",
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo,
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke({"messages": [question]})

response["structured_response"]
# Out:
# CapitalInfo(name='Selene Prime', location='Shackleton Crater rim, lunar south pole', vibe='A gleaming, modular megacity of glass and titanium, with sunlit plazas, transit tubes, and ice-reflection towers; a cosmopolitan hub for diplomacy, science, and the arts.', economy='Extraction and export of helium-3 and water ice, in-situ manufacturing, lunar tourism, and research-driven sectors in astrophysics, life sciences, and advanced materials.')

# %%
response["structured_response"].name
# Out:
# 'Selene Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Selene Prime is a city located at Shackleton Crater rim, lunar south pole
